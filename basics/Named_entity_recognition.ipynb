# %%
import nltk

# %%
sentence='hy my name is nithin and i am a data science student'
words=nltk.word_tokenize(sentence)
elements=nltk.pos_tag(words)

# %%
nltk.ne_chunk(elements).draw()

# %% [markdown]
# ![image.png](attachment:image.png)
